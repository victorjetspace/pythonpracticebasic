# %% [markdown]
# #  Basic of Python

# %%
student = "sam"

# %%
student
# Out:
# 'sam'

# %%
student = "matt"

# %%
student
# Out:
# 'matt'

# %%
student = "bob"

# %%
student
# Out:
# 'bob'

# %%
a1 = 10

# %%
a1
# Out:
# 10

# %%
type(a1)
# Out:
# int

# %%
a1 = 3.139
a1
# Out:
# 3.139

# %%
type(a1)
# Out:
# float

# %%
a1 = True
a1
# Out:
# True

# %%
type(a1)
# Out:
# bool

# %%
a1 = "Hello World"
a1
# Out:
# 'Hello World'

# %%
type(a1)
# Out:
# str

# %%
a1 = 3+4j
a1
# Out:
# (3+4j)

# %%
type(a1)
# Out:
# complex

# %% [markdown]
# # Arithmetic Operators

# %% [markdown]
#  +,-,*,/

# %%
a = 10
b = 20

# %%
a,b
# Out:
# (10, 20)

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %% [markdown]
# # Relational Operators

# %% [markdown]
#  < , > , == ,!=

# %%
a = 50
b = 100

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
& , |
# Out:
#   File "<ipython-input-33-0104695af23d>", line 1
#     & , |
#     ^
# SyntaxError: invalid syntax

# %%
a = True
b = False

# %%
a & a
# Out:
# True

# %%
b & b
# Out:
# False

# %%
a & b
# Out:
# False

# %%
b & a
# Out:
# False

# %%
a | b
# Out:
# True

# %%
b | a
# Out:
# True

# %%
a | a
# Out:
# True

# %%
b | b
# Out:
# False
